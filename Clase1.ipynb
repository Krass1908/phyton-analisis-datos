# %%
print("Hola, futuro analista de datos")
# Out:
# Hola, futuro analista de datos

# %%
nombre= "Carlos"
print(nombre)
# Out:
# Carlos

# %%
edad= "30"
print(edad)
# Out:
# 30

# %%
altura= 1.75
print(altura)
# Out:
# 1.75

# %%
es_analista = True
sabe_nube = False
print(es_analista)
# Out:
# True

# %%
ventas_enero = 1000
ventas_febrero = 1500
total_ventas= ventas_enero + ventas_febrero
print(total_ventas)
# Out:
# 2500
