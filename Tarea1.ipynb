# %%
nombre_empresa = "taller de costura"
empleados = 100
ingreso_mensual = 15400.25
en_la_nube = True

ingreso_anual = ingreso_mensual*12

print("informe de la empresa:")
print(nombre_empresa)
print("ingreso anual proyectado:")
print(ingreso_anual)
# Out:
# informe de la empresa:
# taller de costura
# ingreso anual proyectado:
# 184803.0
