# %%
costo_mensual = 150

if costo_mensual >= 100:
    print("Cliente Premium: Acceso a soporte prioritario.")
elif costo_mensual >= 50:
    print("Cliente Estándar: Acceso a recursos básicos.")
else:
    print("Cliente Básico: Considerar upsell.")
# Out:
# Cliente Premium: Acceso a soporte prioritario.
