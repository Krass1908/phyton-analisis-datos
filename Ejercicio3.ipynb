# %%
uso_cpu = 95
if uso_cpu > 90:
    print("CRITICO El servidor se esta sobrecalentando.")
elif uso_cpu > 70:
    print("ADVERTENCIA El uso es alto, monitorear.")
else:
    print("INFO El servidor esta saludable.")
# Out:
# CRITICO El servidor se esta sobrecalentando.
